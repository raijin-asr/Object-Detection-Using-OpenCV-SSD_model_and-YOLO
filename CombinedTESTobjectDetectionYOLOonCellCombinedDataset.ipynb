# %% [markdown]
# # Training

# %%
import matplotlib.pyplot as plt
from ultralytics import YOLO
import os  # Import the os module

# %%
# Get the directory where the code is executed
current_dir = os.getcwd()

# Load a model
model = YOLO("yolov8n.pt")  # Load the YOLOv8n model

data_path= current_dir + r"\data\Car_Bike_Person_Bicycle-Datasets\data.yaml"
save_path= current_dir + r"\object_results"

# print(data_path)

# Use the model
train_result = model.train(data=data_path, epochs=10, project=save_path)  # Train the model and save results to the specified directory
# Out:
# New https://pypi.org/project/ultralytics/8.2.12 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.2  Python-3.12.3 torch-2.3.0+cpu CPU (12th Gen Intel Core(TM) i5-12450H)
# engine\trainer: task=detect, mode=train, model=yolov8n.pt, data=D:\PROJECTS\Python\Object Detection Project\data\Car_Bike_Person_Bicycle-Datasets\data.yaml, epochs=10, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=D:\PROJECTS\Python\Object Detection Project\object_results, name=train2, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=D:\PROJECTS\Python\Object Detection Project\object_results\train2
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    752092  ultralytics.nn.modules.head.Detect           [4, [64, 128, 256]]
# Model summary: 225 layers, 3011628 parameters, 3011612 gradients
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Scanning D:\PROJECTS\Python\Object Detection Project\data\Car_Bike_Person_Bicycle-Data
# val: Scanning D:\PROJECTS\Python\Object Detection Project\data\Car_Bike_Person_Bicycle-Datase
# val: WARNING  D:\PROJECTS\Python\Object Detection Project\data\Car_Bike_Person_Bicycle-Datasets\valid\images\20220818_13_42_18_761_000_3Du7psGgitewpjIJfxWYyXPV8f73_T_4000_1800_jpg.rf.465046bf27e1a4caacc4159bbf117f85.jpg: ignoring corrupt image/label: cannot reshape array of size 7 into shape (2)
# Plotting labels to D:\PROJECTS\Python\Object Detection Project\object_results\train2\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to D:\PROJECTS\Python\Object Detection Project\object_results\train2
# Starting training for 10 epochs...
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/10         0G      1.207      3.371      1.454         52        640:  34%|███▍

# %%
# trained_image_path = r"D:/PROJECTS/Python/Object Detection Project/object_results/train/confusion_matrix.png"
trained_image_path = r"D:/PROJECTS/Python/Object Detection Project/object_results/train/confusion_matrix.png"

# Load the image using Matplotlib
trained_image = plt.imread(trained_image_path)

# Display the image
plt.figure(figsize=(10, 15))  # Set the figure size to increase width
plt.imshow(trained_image)
plt.axis('off')  # Hide axis
plt.show()

# %%
trained_image_path = r"D:/PROJECTS/Python/Object Detection Project/object_results/train/results.png"

# Load the image using Matplotlib
trained_image = plt.imread(trained_image_path)

# Display the image
plt.figure(figsize=(10, 15))  # Set the figure size to increase width
plt.imshow(trained_image)
plt.axis('off')  # Hide axis
plt.show()

# %%
trained_image_path = r"D:/PROJECTS/Python/Object Detection Project/object_results/train/val_batch0_pred.jpg"

# Load the image using Matplotlib
trained_image = plt.imread(trained_image_path)

# Display the image
plt.figure(figsize=(10, 15))  # Set the figure size to increase width
plt.imshow(trained_image)
plt.axis('off')  # Hide axis
plt.show()

# %% [markdown]
# # Validation

# %%
# Get the directory where the code is executed
current_dir = os.getcwd()

model_path= current_dir + r"\object_results\train2\weights\best.pt"
model = YOLO(model_path)

data_path= current_dir + r"\data\Car_Bike_Person_Bicycle-Datasets\data.yaml"
save_path= current_dir + r"\object_results"

# Evaluate the model's performance on the validation set
validation_results = model.val(data=data_path,project=save_path)
# Out:
# Ultralytics YOLOv8.2.2  Python-3.12.3 torch-2.3.0+cpu CPU (12th Gen Intel Core(TM) i5-12450H)
# Model summary (fused): 168 layers, 3006428 parameters, 0 gradients
# val: Scanning D:\PROJECTS\Python\Object Detection Project\data\Car_Bike_Person_Bicycle-Datase
# val: WARNING  D:\PROJECTS\Python\Object Detection Project\data\Car_Bike_Person_Bicycle-Datasets\valid\images\20220818_13_42_18_761_000_3Du7psGgitewpjIJfxWYyXPV8f73_T_4000_1800_jpg.rf.465046bf27e1a4caacc4159bbf117f85.jpg: ignoring corrupt image/label: cannot reshape array of size 7 into shape (2)
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100
#                    all        181        295      0.725      0.165      0.284      0.152
#                   bike        181         81      0.368      0.425      0.382      0.187
#                    car        181        115      0.533      0.235      0.281      0.157
#                 person        181         76          1          0      0.248      0.158
#                bicycle        181         23          1          0      0.225      0.105
# Speed: 1.1ms preprocess, 70.6ms inference, 0.0ms loss, 3.1ms postprocess per image
# Results saved to D:\PROJECTS\Python\Object Detection Project\object_results\val3

# %%
#showing validated image
validated_image_path = r"D:/PROJECTS/Python/Object Detection Project/object_results/val/val_batch2_pred.jpg"

# Load the image using Matplotlib
validated_image = plt.imread(validated_image_path)

# Display the image
plt.figure(figsize=(10, 15))  # Set the figure size to increase width
plt.imshow(validated_image)
plt.axis('off')  # Hide axis
plt.show()

# %% [markdown]
# # Prediction or Testing

# %%
#Prediction on test images

# Load a model
model_path= current_dir + r"\object_results\train\weights\best.pt"
model = YOLO(model_path)
print(model_path)

source_path= current_dir + r"/data/Car_Bike_Person_Bicycle-Datasets/test/images/Tank-300-Frontier-Edition-x-Buxus-Electric-Bike-main_jpg.rf.e673d1052b4283d612a194b6d3cb5c9f.jpg"
# 
predict_results = model.predict(source=source_path, save=True,imgsz=640, conf=0.25,project=save_path)
# Out:
# D:\PROJECTS\Python\Object Detection Project\object_results\train\weights\best.pt
#
# image 1/1 D:\PROJECTS\Python\Object Detection Project\data\Car_Bike_Person_Bicycle-Datasets\test\images\Tank-300-Frontier-Edition-x-Buxus-Electric-Bike-main_jpg.rf.e673d1052b4283d612a194b6d3cb5c9f.jpg: 640x640 1 bike, 3 cars, 90.3ms
# Speed: 6.6ms preprocess, 90.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to D:\PROJECTS\Python\Object Detection Project\object_results\predict

# %%
#Predicted test images
predicted_image_path = r"D:/PROJECTS/Python/Object Detection Project/object_results/predict/Tank-300-Frontier-Edition-x-Buxus-Electric-Bike-main_jpg.rf.e673d1052b4283d612a194b6d3cb5c9f.jpg"

# Load the image using Matplotlib
predicted_image = plt.imread(predicted_image_path)

# Display the image
plt.figure(figsize=(10, 15))  # Set the figure size to increase width
plt.imshow(predicted_image)
plt.axis('off')  # Hide axis
plt.show()

# %%
#Prediction on webcam or video
from ultralytics import YOLO
import cv2
import os  # Import the os module

# Get the directory where the code is executed
current_dir = os.getcwd()

# Load a model
# model = YOLO("yolov8n.pt")  # Load the YOLOv8n model

model_path= current_dir + r"\object_results\train\weights\best.pt"
# model = YOLO(model_path)

# Open webcam
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()  # Capture frame from webcam
    
    if not ret:
        print("Error: Failed to capture frame")
        break

    # Predict objects on the frame
    predict_results = model.predict(frame, show=True)

    # Check for 'q' key press to close camera
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the webcam and close OpenCV windows
cap.release()
cv2.destroyAllWindows()()
# Out:
# 0: 480x640 (no detections), 74.0ms
# Speed: 0.0ms preprocess, 74.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 94.9ms
# Speed: 0.5ms preprocess, 94.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 80.3ms
# Speed: 1.1ms preprocess, 80.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 bikes, 1 car, 55.0ms
# Speed: 0.0ms preprocess, 55.0ms inference, 13.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 bikes, 66.0ms
# Speed: 0.0ms preprocess, 66.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 63.1ms
# Speed: 0.0ms preprocess, 63.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 bikes, 71.4ms
# Speed: 0.0ms preprocess, 71.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 65.6ms
# Speed: 0.0ms preprocess, 65.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 79.7ms
# Speed: 3.9ms preprocess, 79.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 70.7ms
# Speed: 2.0ms preprocess, 70.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 65.8ms
# Speed: 0.0ms preprocess, 65.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 92.5ms
# Speed: 0.0ms preprocess, 92.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 71.1ms
# Speed: 0.0ms preprocess, 71.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 68.8ms
# Speed: 2.0ms preprocess, 68.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 72.0ms
# Speed: 3.7ms preprocess, 72.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 bikes, 72.4ms
# Speed: 0.0ms preprocess, 72.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 bikes, 69.7ms
# Speed: 0.0ms preprocess, 69.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 bikes, 1 car, 76.2ms
# Speed: 4.3ms preprocess, 76.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 68.5ms
# Speed: 1.0ms preprocess, 68.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 90.8ms
# Speed: 0.0ms preprocess, 90.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 63.2ms
# Speed: 0.0ms preprocess, 63.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 67.5ms
# Speed: 0.0ms preprocess, 67.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 86.0ms
# Speed: 0.0ms preprocess, 86.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 100.0ms
# Speed: 4.0ms preprocess, 100.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 bikes, 1 car, 66.7ms
# Speed: 2.3ms preprocess, 66.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 53.8ms
# Speed: 2.8ms preprocess, 53.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 74.7ms
# Speed: 0.0ms preprocess, 74.7ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 75.6ms
# Speed: 0.0ms preprocess, 75.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 68.4ms
# Speed: 0.0ms preprocess, 68.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 57.7ms
# Speed: 3.1ms preprocess, 57.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 57.6ms
# Speed: 0.0ms preprocess, 57.6ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 87.6ms
# Speed: 0.0ms preprocess, 87.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 2 cars, 58.8ms
# Speed: 0.0ms preprocess, 58.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 56.6ms
# Speed: 2.7ms preprocess, 56.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 66.7ms
# Speed: 4.0ms preprocess, 66.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 bikes, 2 cars, 71.6ms
# Speed: 0.0ms preprocess, 71.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 94.7ms
# Speed: 0.0ms preprocess, 94.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 94.9ms
# Speed: 0.0ms preprocess, 94.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 73.6ms
# Speed: 0.0ms preprocess, 73.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 75.0ms
# Speed: 0.0ms preprocess, 75.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 67.9ms
# Speed: 0.0ms preprocess, 67.9ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 82.4ms
# Speed: 2.9ms preprocess, 82.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 85.0ms
# Speed: 0.0ms preprocess, 85.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 56.1ms
# Speed: 3.5ms preprocess, 56.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 63.5ms
# Speed: 0.0ms preprocess, 63.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 67.9ms
# Speed: 0.0ms preprocess, 67.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 86.3ms
# Speed: 0.0ms preprocess, 86.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 69.1ms
# Speed: 3.6ms preprocess, 69.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 82.4ms
# Speed: 3.0ms preprocess, 82.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 59.6ms
# Speed: 0.0ms preprocess, 59.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 70.2ms
# Speed: 0.0ms preprocess, 70.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 67.7ms
# Speed: 0.0ms preprocess, 67.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 59.4ms
# Speed: 0.0ms preprocess, 59.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 73.1ms
# Speed: 0.0ms preprocess, 73.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 74.2ms
# Speed: 0.0ms preprocess, 74.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 68.7ms
# Speed: 0.7ms preprocess, 68.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 69.1ms
# Speed: 0.0ms preprocess, 69.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 67.4ms
# Speed: 2.8ms preprocess, 67.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 63.5ms
# Speed: 0.0ms preprocess, 63.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 92.8ms
# Speed: 0.0ms preprocess, 92.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 62.0ms
# Speed: 0.0ms preprocess, 62.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 73.7ms
# Speed: 0.0ms preprocess, 73.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 65.5ms
# Speed: 2.9ms preprocess, 65.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 74.0ms
# Speed: 0.0ms preprocess, 74.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 84.6ms
# Speed: 0.0ms preprocess, 84.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 69.0ms
# Speed: 0.0ms preprocess, 69.0ms inference, 8.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 69.8ms
# Speed: 0.0ms preprocess, 69.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 70.1ms
# Speed: 3.2ms preprocess, 70.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 82.0ms
# Speed: 3.2ms preprocess, 82.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 56.9ms
# Speed: 0.0ms preprocess, 56.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 83.5ms
# Speed: 0.0ms preprocess, 83.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 56.2ms
# Speed: 3.6ms preprocess, 56.2ms inference, 14.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 63.0ms
# Speed: 0.0ms preprocess, 63.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 66.3ms
# Speed: 0.0ms preprocess, 66.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 54.7ms
# Speed: 2.8ms preprocess, 54.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 67.5ms
# Speed: 3.4ms preprocess, 67.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 93.3ms
# Speed: 6.4ms preprocess, 93.3ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 54.4ms
# Speed: 0.0ms preprocess, 54.4ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 76.8ms
# Speed: 2.6ms preprocess, 76.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 68.5ms
# Speed: 0.0ms preprocess, 68.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 71.3ms
# Speed: 0.0ms preprocess, 71.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 68.6ms
# Speed: 4.9ms preprocess, 68.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 73.0ms
# Speed: 0.0ms preprocess, 73.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 68.9ms
# Speed: 0.0ms preprocess, 68.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 65.5ms
# Speed: 0.0ms preprocess, 65.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 58.5ms
# Speed: 3.4ms preprocess, 58.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 61.1ms
# Speed: 0.0ms preprocess, 61.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 78.7ms
# Speed: 0.0ms preprocess, 78.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 66.0ms
# Speed: 0.0ms preprocess, 66.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 67.8ms
# Speed: 0.0ms preprocess, 67.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 69.5ms
# Speed: 0.0ms preprocess, 69.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 71.0ms
# Speed: 3.0ms preprocess, 71.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 70.3ms
# Speed: 1.4ms preprocess, 70.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 74.8ms
# Speed: 0.0ms preprocess, 74.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 78.9ms
# Speed: 0.0ms preprocess, 78.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 60.3ms
# Speed: 4.1ms preprocess, 60.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 67.9ms
# Speed: 2.0ms preprocess, 67.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 58.4ms
# Speed: 0.0ms preprocess, 58.4ms inference, 12.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 72.5ms
# Speed: 0.0ms preprocess, 72.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 68.1ms
# Speed: 0.0ms preprocess, 68.1ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 74.4ms
# Speed: 0.0ms preprocess, 74.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 71.4ms
# Speed: 0.0ms preprocess, 71.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 67.7ms
# Speed: 0.0ms preprocess, 67.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 84.9ms
# Speed: 2.0ms preprocess, 84.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 61.2ms
# Speed: 0.0ms preprocess, 61.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 100.6ms
# Speed: 0.0ms preprocess, 100.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 69.1ms
# Speed: 0.0ms preprocess, 69.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 66.7ms
# Speed: 2.0ms preprocess, 66.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 bikes, 1 car, 68.3ms
# Speed: 0.0ms preprocess, 68.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 61.7ms
# Speed: 0.0ms preprocess, 61.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 78.6ms
# Speed: 0.0ms preprocess, 78.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 87.6ms
# Speed: 2.4ms preprocess, 87.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 73.2ms
# Speed: 0.0ms preprocess, 73.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 85.3ms
# Speed: 1.1ms preprocess, 85.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 66.6ms
# Speed: 3.0ms preprocess, 66.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 2 cars, 68.8ms
# Speed: 0.0ms preprocess, 68.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 bikes, 1 car, 61.7ms
# Speed: 0.0ms preprocess, 61.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 69.4ms
# Speed: 0.0ms preprocess, 69.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 66.3ms
# Speed: 0.5ms preprocess, 66.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 69.6ms
# Speed: 0.0ms preprocess, 69.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 bikes, 1 car, 71.2ms
# Speed: 0.0ms preprocess, 71.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 58.2ms
# Speed: 0.0ms preprocess, 58.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 2 cars, 63.2ms
# Speed: 2.0ms preprocess, 63.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 71.4ms
# Speed: 0.0ms preprocess, 71.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 67.6ms
# Speed: 0.0ms preprocess, 67.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 bikes, 2 cars, 55.4ms
# Speed: 3.7ms preprocess, 55.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 bikes, 1 car, 81.4ms
# Speed: 2.3ms preprocess, 81.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 bikes, 1 car, 68.9ms
# Speed: 0.0ms preprocess, 68.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 66.3ms
# Speed: 2.0ms preprocess, 66.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 bikes, 64.8ms
# Speed: 0.0ms preprocess, 64.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 59.9ms
# Speed: 0.0ms preprocess, 59.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 bikes,
ms preprocess, 69.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 70.3ms
# Speed: 0.0ms preprocess, 70.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 67.8ms
# Speed: 2.3ms preprocess, 67.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 63.9ms
# Speed: 1.1ms preprocess, 63.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 65.0ms
# Speed: 4.0ms preprocess, 65.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 68.1ms
# Speed: 0.0ms preprocess, 68.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 77.5ms
# Speed: 1.0ms preprocess, 77.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 66.8ms
# Speed: 1.8ms preprocess, 66.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 66.6ms
# Speed: 0.0ms preprocess, 66.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 69.0ms
# Speed: 0.0ms preprocess, 69.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 76.9ms
# Speed: 1.0ms preprocess, 76.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 80.0ms
# Speed: 2.0ms preprocess, 80.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 75.3ms
# Speed: 2.9ms preprocess, 75.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 85.8ms
# Speed: 0.0ms preprocess, 85.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 65.6ms
# Speed: 3.1ms preprocess, 65.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 66.2ms
# Speed: 3.6ms preprocess, 66.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 81.3ms
# Speed: 3.6ms preprocess, 81.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 66.4ms
# Speed: 2.3ms preprocess, 66.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 79.0ms
# Speed: 1.9ms preprocess, 79.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 65.1ms
# Speed: 1.0ms preprocess, 65.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 68.1ms
# Speed: 0.0ms preprocess, 68.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 67.8ms
# Speed: 0.0ms preprocess, 67.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 67.8ms
# Speed: 1.1ms preprocess, 67.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 69.3ms
# Speed: 0.0ms preprocess, 69.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 76.7ms
# Speed: 0.0ms preprocess, 76.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 71.9ms
# Speed: 2.0ms preprocess, 71.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 77.8ms
# Speed: 2.0ms preprocess, 77.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 65.0ms
# Speed: 3.5ms preprocess, 65.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 67.7ms
# Speed: 2.3ms preprocess, 67.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 67.3ms
# Speed: 3.6ms preprocess, 67.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 84.5ms
# Speed: 0.0ms preprocess, 84.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 77.0ms
# Speed: 2.0ms preprocess, 77.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 79.5ms
# Speed: 1.0ms preprocess, 79.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 74.4ms
# Speed: 4.0ms preprocess, 74.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 91.3ms
# Speed: 2.0ms preprocess, 91.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 105.4ms
# Speed: 2.9ms preprocess, 105.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 2 cars, 67.9ms
# Speed: 1.3ms preprocess, 67.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 98.1ms
# Speed: 1.0ms preprocess, 98.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 78.1ms
# Speed: 2.3ms preprocess, 78.1ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 80.5ms
# Speed: 0.0ms preprocess, 80.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 69.6ms
# Speed: 0.0ms preprocess, 69.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 80.3ms
# Speed: 4.4ms preprocess, 80.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cars, 94.3ms
# Speed: 0.4ms preprocess, 94.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 81.7ms
# Speed: 0.6ms preprocess, 81.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 73.2ms
# Speed: 3.9ms preprocess, 73.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 70.3ms
# Speed: 2.5ms preprocess, 70.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 69.8ms
# Speed: 0.0ms preprocess, 69.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 64.1ms
# Speed: 1.0ms preprocess, 64.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bike, 1 car, 67.3ms
# Speed: 0.0ms preprocess, 67.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 82.4ms
# Speed: 0.0ms preprocess, 82.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 80.2ms
# Speed: 5.2ms preprocess, 80.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 94.5ms
# Speed: 0.5ms preprocess, 94.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 64.7ms
# Speed: 1.0ms preprocess, 64.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 72.6ms
# Speed: 0.0ms preprocess, 72.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 73.6ms
# Speed: 1.0ms preprocess, 73.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 66.4ms
# Speed: 1.3ms preprocess, 66.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 65.0ms
# Speed: 1.1ms preprocess, 65.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 73.9ms
# Speed: 0.8ms preprocess, 73.9ms inference, 7.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 85.7ms
# Speed: 2.0ms preprocess, 85.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 95.8ms
# Speed: 0.0ms preprocess, 95.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 95.0ms
# Speed: 3.8ms preprocess, 95.0ms inference, 0.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 64.8ms
# Speed: 1.6ms preprocess, 64.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 65.1ms
# Speed: 1.0ms preprocess, 65.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 106.2ms
# Speed: 1.9ms preprocess, 106.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 66.7ms
# Speed: 2.0ms preprocess, 66.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 70.2ms
# Speed: 0.0ms preprocess, 70.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 59.4ms
# Speed: 0.2ms preprocess, 59.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 61.8ms
# Speed: 1.5ms preprocess, 61.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 65.4ms
# Speed: 1.5ms preprocess, 65.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 81.8ms
# Speed: 0.0ms preprocess, 81.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 71.4ms
# Speed: 0.0ms preprocess, 71.4ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 95.4ms
# Speed: 0.0ms preprocess, 95.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 74.7ms
# Speed: 0.0ms preprocess, 74.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 82.9ms
# Speed: 0.0ms preprocess, 82.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 79.5ms
# Speed: 0.0ms preprocess, 79.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 83.9ms
# Speed: 3.0ms preprocess, 83.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 97.3ms
# Speed: 0.0ms preprocess, 97.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 71.4ms
# Speed: 2.0ms preprocess, 71.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 69.8ms
# Speed: 1.1ms preprocess, 69.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 64.9ms
# Speed: 0.0ms preprocess, 64.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 83.9ms
# Speed: 0.0ms preprocess, 83.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 66.1ms
# Speed: 0.0ms preprocess, 66.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 80.0ms
# Speed: 0.0ms preprocess, 80.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 66.3ms
# Speed: 0.0ms preprocess, 66.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 80.7ms
# Speed: 0.0ms preprocess, 80.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 26
#      23     break
#      25 # Predict objects on the frame
# ---> 26 predict_results = model.predict(frame, show=True)
#      28 # Check for 'q' key press to close camera
#      29 if cv2.waitKey(1) & 0xFF == ord('q'):
#
# File D:\PROJECTS\Python\Object Detection Project\objenv\Lib\site-packages\ultralytics\engine\model.py:452, in Model.predict(self, source, stream, predictor, **kwargs)
#     450 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     451     self.predictor.set_prompts(prompts)
# --> 452 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File D:\PROJECTS\Python\Object Detection Project\objenv\Lib\site-packages\ultralytics\engine\predictor.py:168, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     166     return self.stream_inference(source, model, *args, **kwargs)
#     167 else:
# --> 168     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File D:\PROJECTS\Python\Object Detection Project\objenv\Lib\site-packages\torch\utils\_contextlib.py:35, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      32 try:
#      33     # Issuing `None` to a generator fires it up
#      34     with ctx_factory():
# ---> 35         response = gen.send(None)
#      37     while True:
#      38         try:
#      39             # Forward the response to our caller and get its next request
#
# File D:\PROJECTS\Python\Object Detection Project\objenv\Lib\site-packages\ultralytics\engine\predictor.py:268, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     262     self.results[i].speed = {
#     263         "preprocess": profilers[0].dt * 1e3 / n,
#     264         "inference": profilers[1].dt * 1e3 / n,
#     265         "postprocess": profilers[2].dt * 1e3 / n,
#     266     }
#     267     if self.args.verbose or self.args.save or self.args.save_txt or self.args.show:
# --> 268         s[i] += self.write_results(i, Path(paths[i]), im, s)
#     270 # Print batch results
#     271 if self.args.verbose:
#
# File D:\PROJECTS\Python\Object Detection Project\objenv\Lib\site-packages\ultralytics\engine\predictor.py:346, in BasePredictor.write_results(self, i, p, im, s)
#     344     result.save_crop(save_dir=self.save_dir / "crops", file_name=self.txt_path.stem)
#     345 if self.args.show:
# --> 346     self.show(str(p))
#     347 if self.args.save:
#     348     self.save_predicted_images(str(self.save_dir / p.name), frame)
#
# File D:\PROJECTS\Python\Object Detection Project\objenv\Lib\site-packages\ultralytics\engine\predictor.py:388, in BasePredictor.show(self, p)
#     386     cv2.resizeWindow(p, im.shape[1], im.shape[0])  # (width, height)
#     387 cv2.imshow(p, im)
# --> 388 cv2.waitKey(300 if self.dataset.mode == "image" else 1)
#
# KeyboardInterrupt:
